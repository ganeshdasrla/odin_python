# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshdasrla/odin_python/blob/main/Genai_8june.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Different ways to access LLM's
# Ollma set up to use different llm
# Prompt engineering

# %%
# %%capture
# !pip install openai

# %%
# write a function to add 2 numbers
def add(x, y):
  return x + y

# %%
from google.colab import userdata
api_key=userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, describe everything asked in a funny way."},
    {"role": "user", "content": "Compose a poem that explains rcb's poor performance in IPL."}
  ]
)

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-9XiUOMwpFLSCDLIAAEoQSgrxCYVma', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="In the land of IPL so bright,  \nThere lies a team that causes fright.  \nRCB, oh RCB, what a plight!  \nTheir poor performance shines so light.  \n\nVirat Kohli, a mighty man,  \nBut even he can't stick to the plan.  \nThe bowlers suffer, batsmen in a jam,  \nOh RCB, you need a new game plan!  \n\nEach season brings hope anew,  \nBut alas, their destiny remains askew.  \nFans keep hoping, praying too,  \nMaybe next year, RCB will debut in blue!  \n\nSo here we are, with hearts so torn,  \nWatching RCB like a rose with thorn.  \nBut fear not, for in cricket we trust,  \nNext season may bring success robust!", role='assistant', function_call=None, tool_calls=None))], created=1717822868, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=160, prompt_tokens=38, 
# ...

# %%
completion.choices
# Out:
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="In the land of IPL so bright,  \nThere lies a team that causes fright.  \nRCB, oh RCB, what a plight!  \nTheir poor performance shines so light.  \n\nVirat Kohli, a mighty man,  \nBut even he can't stick to the plan.  \nThe bowlers suffer, batsmen in a jam,  \nOh RCB, you need a new game plan!  \n\nEach season brings hope anew,  \nBut alas, their destiny remains askew.  \nFans keep hoping, praying too,  \nMaybe next year, RCB will debut in blue!  \n\nSo here we are, with hearts so torn,  \nWatching RCB like a rose with thorn.  \nBut fear not, for in cricket we trust,  \nNext season may bring success robust!", role='assistant', function_call=None, tool_calls=None))]

# %%
completion.choices[0].message.content
# Out:
# "In the land of IPL so bright,  \nThere lies a team that causes fright.  \nRCB, oh RCB, what a plight!  \nTheir poor performance shines so light.  \n\nVirat Kohli, a mighty man,  \nBut even he can't stick to the plan.  \nThe bowlers suffer, batsmen in a jam,  \nOh RCB, you need a new game plan!  \n\nEach season brings hope anew,  \nBut alas, their destiny remains askew.  \nFans keep hoping, praying too,  \nMaybe next year, RCB will debut in blue!  \n\nSo here we are, with hearts so torn,  \nWatching RCB like a rose with thorn.  \nBut fear not, for in cricket we trust,  \nNext season may bring success robust!"

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "Act like a customer service representative and respond to the customers feedback politely"},
    {"role": "user", "content": "You offer terrible service and I hate buying from you"}
  ]
)

# %%
completion.choices[0].message.content
# Out:
# "I'm sorry to hear that your experience with our service has not met your expectations. We truly value your feedback and would like to make things right. Please let us know how we can improve and what we can do to regain your trust as a customer. Thank you for bringing this to our attention."

# %%
# Dalle-3 for text to image generation
response=client.images.generate(model="dall-e-3",prompt="a white siamese cat",size="1024x1024",quality="standard",n=1,)

# %%
response.data[0].url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-SccctNIlBMC3o7Rsd8Siohe4/user-QxA5KE2U7wMtkPKENifAfEVK/img-9oHXaLE3GDZrvcOCzFoHRNdz.png?st=2024-06-08T04%3A11%3A28Z&se=2024-06-08T06%3A11%3A28Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-07T16%3A56%3A55Z&ske=2024-06-08T16%3A56%3A55Z&sks=b&skv=2023-11-03&sig=mf48WlP36jOIbGOy7440ByqVCKfLbsI2XOUKSKb/X6s%3D'

# %%
response=client.images.generate(model="dall-e-3",prompt="Virat kohli smashing a six",size="1024x1024",quality="standard",n=1,)

# %%
response.data[0].url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-SccctNIlBMC3o7Rsd8Siohe4/user-QxA5KE2U7wMtkPKENifAfEVK/img-WysAOhOl99soFm6X5Ia2k4hR.png?st=2024-06-08T04%3A14%3A02Z&se=2024-06-08T06%3A14%3A02Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-07T08%3A43%3A28Z&ske=2024-06-08T08%3A43%3A28Z&sks=b&skv=2023-11-03&sig=EGdRkPVMGCUIxC%2BRZ2oA6RgpO03Gf64EMKcRD81lerU%3D'

# %%
from google.colab import userdata
gemini_key=userdata.get('Geminiprokey')

# %%
# %%capture
# !pip install google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key=gemini_key)

# gemini pro works for text to text
model = genai.GenerativeModel(model_name='gemini-pro')
response = model.generate_content('Can you explain encoder-decoder blocks for a kid?')

# %%
def gemini_pro(question):
  model = genai.GenerativeModel(model_name='gemini-pro')
  response = model.generate_content(question)
  return response.text

# %%
gemini_pro("When was APJ Abdul Kalam born?")
# Out:
# 'October 15, 1931'

# %%
# %%capture
pip install gradio

# %%
import gradio as gr

# %%
# demo=gr.Interface(fn=gemini_pro, inputs="text", outputs="text")
# demo.launch(share=True)

# %%
# text to text
# text to image
# image - text?

# we can do this using gemini-pro-vision

# %%
gemini_image_description=genai.GenerativeModel(model_name="gemini-pro-vision")

# %%
import PIL.Image

# %%
image=PIL.Image.open("/content/destination.jpg.webp")

# %%
image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=728x524 at 0x78A527DF7A00>

# %%
response = gemini_image_description.generate_content(["Write a short, engaging blog post based on this picture",image],stream=True)
response.resolve()
response.text
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-e86f653bd2d0> in <cell line: 1>()
# ----> 1 response = gemini_image_description.generate_content(["Write a short, engaging blog post based on this picture",image],stream=True)
#       2 response.resolve()
#       3 response.text
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     254             if stream:
#     255                 with generation_types.rewrite_stream_error():
# --> 256                     iterator = self._client.stream_generate_content(
#     257                         request,
#     258                         **request_options,
#
# ...

# %%
response.text
# Out:
# "Sure, here is a simplified explanation of encoder-decoder blocks for a kid:\n\n**Encoder-decoder blocks** are like special building blocks that are used to make a machine learning model that can take in data, understand it, and then create new data or make predictions. Here's how they work:\n\n**Encoder blocks:**\n\n* Imagine a toy box that is filled with different colored balls.\n* The encoder blocks are like machines that can take these balls and turn them into a special code.\n* This code is like a secret message that represents the balls in the box.\n\n**Decoder blocks:**\n\n* The decoder blocks are like machines that can take the secret code and turn it back into balls.\n* They do this by understanding the code and figuring out which balls it represents.\n\n**Putting it all together:**\n\n* The encoder blocks and decoder blocks work together like a team.\n* The encoder blocks take in data and turn it into a code.\n* The decoder blocks then take the code and turn it back into da
# ...

# %%
print(response.text)
# Out:
# Sure, here is a simplified explanation of encoder-decoder blocks for a kid:
#
# **Encoder-decoder blocks** are like special building blocks that are used to make a machine learning model that can take in data, understand it, and then create new data or make predictions. Here's how they work:
#
# **Encoder blocks:**
#
# * Imagine a toy box that is filled with different colored balls.
# * The encoder blocks are like machines that can take these balls and turn them into a special code.
# * This code is like a secret message that represents the balls in the box.
#
# **Decoder blocks:**
#
# * The decoder blocks are like machines that can take the secret code and turn it back into balls.
# * They do this by understanding the code and figuring out which balls it represents.
#
# **Putting it all together:**
#
# * The encoder blocks and decoder blocks work together like a team.
# * The encoder blocks take in data and turn it into a code.
# ...

# %%
demo = gr.Interface(fn=gemini_pro,
                    inputs=[gr.Textbox(label="Input Text", lines=3)],
                    outputs=[gr.Textbox(label="Result", lines=2)],
                    title="Text 2 text generation",
                   )
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://bcf9fe2865a28b5696.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://bcf9fe2865a28b5696.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# %%capture
pip install openai

# %%
import pandas as pd

# %%
from openai import OpenAI
client =OpenAI(api_key="")

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# Tricks to interact with the model
# Trick1 : Use delimiters to clearly indicate distinct parts of the input¶
# Delimiters can be anything like: ```, """, < >, <tag> </tag>, :

text = f"""
You should express what you want a model to do by \
providing instructions that are as clear and \
specific as you can possibly make them. \
This will guide the model towards the desired output, \
and reduce the chances of receiving irrelevant \
or incorrect responses. Don't confuse writing a \
clear prompt with writing a short prompt. \
In many cases, longer prompts provide more clarity \
and context for the model, which can lead to \
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-b3920af934c5> in <cell line: 22>()
#      20 ```{text}```
#      21 """
# ---> 22 response = get_completion(prompt)
#      23 print(response)
#
# <ipython-input-68-9a066cc30622> in get_completion(prompt, model)
#       1 def get_completion(prompt, model="gpt-3.5-turbo"):
#       2     messages = [{"role": "user", "content": prompt}]
# ----> 3     response = client.ChatCompletion.create(
#       4         model=model,
#       5         messages=messages,
#
# AttributeError: 'OpenAI' object has no attribute 'ChatCompletion'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
# Tricks to interact with the model
# principle1: clear and specific instructions
# Trick1 : Use delimiters to clearly indicate distinct parts of the input¶
# Delimiters can be anything like: ```, """, < >, <tag> </tag>, :

text = f"""
You should express what you want a model to do by \
providing instructions that are as clear and \
specific as you can possibly make them. \
This will guide the model towards the desired output, \
and reduce the chances of receiving irrelevant \
or incorrect responses. Don't confuse writing a \
clear prompt with writing a short prompt. \
In many cases, longer prompts provide more clarity \
and context for the model, which can lead to \
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Providing clear and specific instructions to a model will guide it towards the desired output, reducing the chances of irrelevant or incorrect responses, and longer prompts can provide more clarity and context for more detailed and relevant outputs.

# %%
print(response)
# Out:
# Providing clear and specific instructions to a model will guide it towards the desired output, reducing the chances of irrelevant or incorrect responses, and longer prompts can provide more clarity and context for more detailed and relevant outputs.

# %%
# Tricke 2: asked for a structured output
prompt = f"""
Generate a list of three made-up book titles along \
with their authors and genres.
Provide them in JSON format with the following keys:
book_id, title, author, genre.
"""
response = get_completion(prompt)
print(response)
# Out:
# [
#     {
#         "book_id": 1,
#         "title": "The Midnight Garden",
#         "author": "Elena Rivers",
#         "genre": "Fantasy"
#     },
#     {
#         "book_id": 2,
#         "title": "Whispers in the Wind",
#         "author": "Lucas Blackwood",
#         "genre": "Mystery"
#     },
#     {
#         "book_id": 3,
#         "title": "Echoes of the Past",
#         "author": "Aria Summers",
#         "genre": "Romance"
#     }
# ]

# %%
# Ask the model to check whether conditions are satisfied

text_1 = f"""
Making a cup of tea is easy! First, you need to get some \
water boiling. While that's happening, \
grab a cup and put a tea bag in it. Once the water is \
hot enough, just pour it over the tea bag. \
Let it sit for a bit so the tea can steep. After a \
few minutes, take out the tea bag. If you \
like, you can add some sugar or milk to taste. \
And that's it! You've got yourself a delicious \
cup of tea to enjoy.
"""
prompt = f"""
You will be provided with text delimited by triple quotes.
If it contains a sequence of instructions, \
re-write those instructions in the following format:

Step 1 - ...
Step 2 - …
…
Step N - …

If the text does not contain a sequence of instructions, \
then simply write \"No steps provided.\"

\"\"\"{text_1}\"\"\"
"""
response = get_completion(prompt)
print("Completion for Text 1:")
print(response)
# Out:
# Completion for Text 1:
# Step 1 - Get some water boiling.
# Step 2 - Grab a cup and put a tea bag in it.
# Step 3 - Once the water is hot enough, pour it over the tea bag.
# Step 4 - Let it sit for a bit so the tea can steep.
# Step 5 - After a few minutes, take out the tea bag.
# Step 6 - Add some sugar or milk to taste.
# Step 7 - Enjoy your delicious cup of tea.

# %%
text_2 = f"""
The sun is shining brightly today, and the birds are \
singing. It's a beautiful day to go for a \
walk in the park. The flowers are blooming, and the \
trees are swaying gently in the breeze. People \
are out and about, enjoying the lovely weather. \
Some are having picnics, while others are playing \
games or simply relaxing on the grass. It's a \
perfect day to spend time outdoors and appreciate the \
beauty of nature.
"""
prompt = f"""
You will be provided with text delimited by triple quotes.
If it contains a sequence of instructions, \
re-write those instructions in the following format:

Step 1 - ...
Step 2 - …
…
Step N - …

If the text does not contain a sequence of instructions, \
then simply write \"No steps provided.\"

\"\"\"{text_2}\"\"\"
"""
response = get_completion(prompt)
print("Completion for Text 2:")
print(response)
# Out:
# Completion for Text 2:
# No steps provided.

# %%
# trick4:
#Zero-shot prompting- whenever we ask a question to the model without giving any examples
# One shot prompting- whenever we ask a question to the model by giving one example
# few shot prompting - whenever we ask a question to the model by giving multiple examples

# %%
# principle2- give the model time to think
# tricks1:specify the steps required to complete a task

text = f"""
In a charming village, siblings Jack and Jill set out on \
a quest to fetch water from a hilltop \
well. As they climbed, singing joyfully, misfortune \
struck—Jack tripped on a stone and tumbled \
down the hill, with Jill following suit. \
Though slightly battered, the pair returned home to \
comforting embraces. Despite the mishap, \
their adventurous spirits remained undimmed, and they \
continued exploring with delight.
"""
# example 1
prompt_1 = f"""
Perform the following actions:
1 - Summarize the following text delimited by triple \
backticks with 1 sentence.
2 - Translate the summary into Hindi.
3 - List each name in the Hindi summary.
4 - Output a json object that contains the following \
keys: Hindi_summary, num_names.

Separate your answers with line breaks.

Text:
```{text}```
"""
response = get_completion(prompt_1)
print("Completion for prompt 1:")
print(response)
# Out:
# Completion for prompt 1:
# 1 - Jack and Jill, siblings from a charming village, go on a quest to fetch water from a hilltop well, but encounter misfortune along the way.
#
# 2 - एक प्यारे गाँव में, भाई बहन जैक और जिल एक कुए के पानी लाने के लिए एक खोज पर निकलते हैं, लेकिन रास्ते में दुर्भाग्य का सामना करते हैं।
#
# 3 - जैक, जिल
#
# 4 -
# {
#   "Hindi_summary": "एक प्यारे गाँव में, भाई बहन जैक और जिल एक कुए के पानी लाने के लिए एक खोज पर निकलते हैं, लेकिन रास्ते में दुर्भाग्य का सामना करते हैं।",
#   "num_names": 2
# }

# %%
# Trick2 2: Instruct the model to work out its own solution before rushing to a conclusion

prompt = f"""
Determine if the student's solution is correct or not.

Question:
I'm building a solar power installation and I need \
 help working out the financials.
- Land costs $100 / square foot
- I can buy solar panels for $250 / square foot
- I negotiated a contract for maintenance that will cost \
me a flat $100k per year, and an additional $10 / square \
foot
What is the total cost for the first year of operations
as a function of the number of square feet.

Student's Solution:
Let x be the size of the installation in square feet.
Costs:
1. Land cost: 100x
2. Solar panel cost: 250x
3. Maintenance cost: 100,000 + 100x
Total cost: 100x + 250x + 100,000 + 100x = 450x + 100,000
"""
response = get_completion(prompt)
print(response)
# Out:
# The student's solution is correct. The total cost for the first year of operations as a function of the number of square feet is indeed 450x + 100,000.

# %%
prompt = f"""
Your task is to determine if the student's solution \
is correct or not.
To solve the problem do the following:
- First, work out your own solution to the problem including the final total.
- Then compare your solution to the student's solution \
and evaluate if the student's solution is correct or not.
Don't decide if the student's solution is correct until
you have done the problem yourself.

Use the following format:
Question:
```
question here
```
Student's solution:
```
student's solution here
```
Actual solution:
```
steps to work out the solution and your solution here
```
Is the student's solution the same as actual solution \
just calculated:
```
yes or no
```
Student grade:
```
correct or incorrect
```

Question:
```
I'm building a solar power installation and I need help \
working out the financials.
- Land costs $100 / square foot
- I can buy solar panels for $250 / square foot
- I negotiated a contract for maintenance that will cost \
me a flat $100k per year, and an additional $10 / square \
foot
What is the total cost for the first year of operations \
as a function of the number of square feet.
```
Student's solution:
```
Let x be the size of the installation in square feet.
Costs:
1. Land cost: 100x
2. Solar panel cost: 250x
3. Maintenance cost: 100,000 + 100x
Total cost: 100x + 250x + 100,000 + 100x = 450x + 100,000
```
Actual solution:
"""
response = get_completion(prompt)
print(response)
# Out:
# Let's calculate the total cost for the first year of operations as a function of the number of square feet.
#
# Given:
# - Land cost: $100 / square foot
# - Solar panel cost: $250 / square foot
# - Maintenance cost: $100,000 per year + $10 / square foot
#
# Let x be the size of the installation in square feet.
#
# Total cost:
# 1. Land cost: $100 * x
# 2. Solar panel cost: $250 * x
# 3. Maintenance cost: $100,000 + $10 * x
#
# Total cost = Land cost + Solar panel cost + Maintenance cost
# Total cost = $100x + $250x + $100,000 + $10x
# Total cost = $360x + $100,000
#
# Therefore, the total cost for the first year of operations as a function of the number of square feet is 360x + 100,000.
#
# Is the student's solution the same as the actual solution just calculated:
# ```
# No
# ```
# Student grade:
# ```
# Incorrect
# ```

# %% [markdown]
# # Hallucination

# %%
prompt = f"""
Tell me about AeroGlide UltraSlim Smart Toothbrush by Odinschool
"""
response = get_completion(prompt)
print(response)
# Out:
# The AeroGlide UltraSlim Smart Toothbrush by Odinschool is a high-tech toothbrush designed to provide a superior cleaning experience. It features a sleek and slim design that makes it easy to hold and maneuver in the mouth. The toothbrush uses advanced sonic technology to deliver up to 40,000 brush strokes per minute, effectively removing plaque and debris from the teeth and gums.
#
# The AeroGlide UltraSlim Smart Toothbrush also comes equipped with smart features such as a built-in timer and pressure sensor to help users brush their teeth more effectively and prevent over-brushing. It connects to a mobile app via Bluetooth, allowing users to track their brushing habits and receive personalized recommendations for improving their oral hygiene routine.
#
# Overall, the AeroGlide UltraSlim Smart Toothbrush is a cutting-edge dental tool that combines innovative technology with sleek design to provide users with a superior cleaning experience.

# %%
# First prompt engineering
# Fine tuning
# Retrieval Augmented Generation

# %%
prompt = f"""
What is the duration of data science bootcamp at Odinschool
"""
response = get_completion(prompt)
print(response)
# Out:
# The duration of the data science bootcamp at Odinschool is typically 12 weeks.

# %%
# word embedding
# vector databsaes
# RAG

# %% [markdown]
# # RAG Implementation using Python

# %%
# %%capture
# !pip install langchain # create rag application
# !pip install pypdf # to store pdf
# !pip install sentence-transformers==2.2.2 # to create embeddings

# %%
# %%capture
# !pip install openai # large language model
# !pip install tiktoken
# !pip install faiss-cpu # vectordatabase

# %%
# !mkdir pdfs

# %%
# !pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# load pypdfdirectory loader from langchain
from langchain_community.document_loaders import PyPDFDirectoryLoader

# %%
loader=PyPDFDirectoryLoader("pdfs")

# %%
data=loader.load()

# %%
# I need to create chunks using recrusivecharactersplitter
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=100)

# %%
chunks=splitter.split_documents(data)

# %%
chunks[2]
# Out:
# Document(page_content='that\nreduced\ntickets\nby\n20%\n●\nDevelop\naction\nplans\nto\nmitigate\nrisks\nin\ndecision\nmaking\nwhile\nincreasing\nprofitability\nby\nleveraging\ndata\nscience.\n●\nDrive\nthe\ninteraction\nand\npartnership\nbetween\nthe\nmanagers', metadata={'source': 'pdfs/Mujeeb_resume-4.pdf', 'page': 0})

# %%
len(chunks)
# Out:
# 6

# %%
# load the huggingface embeddings class
from langchain.embeddings import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# .gitattributes:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/90.4M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
# call the vectordatabase faiss from langchain
from langchain.vectorstores import FAISS
vectordabase=FAISS.from_documents(chunks,embeddings)

# %%
query="what is mujeeb's email address?"
docs=vectordabase.similarity_search(query,k=2)

# %%
docs
# Out:
# [Document(page_content="Shaik\nMujeeb\nUr\nRahman\nmujeebr469@gmail.com\n,\n9949308887\nSkills:\nGenerative\nAI,Large\nlanguage\nmodels,Python,Machine\nLearning,SQL,POWER\nBI,Deep\nLearning,NLP,Langchain,\nGradio,Hugging\nFace,Chainlit,Langsmith.\nGithub:\nhttps://github.com/dashboard\nLinkedin:\nhttps://www.linkedin.com/in/shaik-mujeeb-a0a8b8131/\nData\nScientist\nwith\n6+\nyears\nof\nbroad-based\nexperience\nin\nbuilding\ndata-intensive\napplications,\novercoming\ncomplex\narchitectural,\nand\nscalability\nissues\nin\ndiverse\nindustries.\nProficient\nin\npredictive\nmodeling,\ndata\nprocessing,feature\nengineering,\nEDA\n,Machine\nLearning,\nDeep\nLearning,NLP,\nLarge\nLanguage\nModels,\nLangchain,Ollama,Python\nand\nSQL,Power\nBI.\nProjects\n:\n●\nDeveloped\nand\ndeployed\nRAG\napplication\nto\ninteract\nwith\nOdin\nSchool's\nwebsite\nusing\nChromadb\nvector\ndatabase,ollama\nand\nLlama2\nLLM\non\nStreamlit.\n●\nDeveloped\nand\ndeployed\nData\nAnalysis\nApp\nusing\nPandasAI\nand\
# ...

# %%
# define llm from openai using langchain
from langchain.llms import OpenAI

# %%
from google.colab import userdata
api_key=userdata.get('open_ai')

# %%
llm=OpenAI(api_key=api_key)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
# import the retrievalqa chain from langchain
from langchain.chains import RetrievalQA

# %%
results=RetrievalQA.from_chain_type(llm=llm,chain_type="stuff",retriever=vectordabase.as_retriever())

# %%
results.run("what are the skills of mujeeb?")
# Out:
# ' According to the given context, some of the skills of Mujeeb are Generative AI, Large language models, Python, Machine Learning, SQL, POWER BI, Deep Learning, NLP, Langchain, Gradio, Hugging Face, Chainlit, Langsmith.'

# %%
# creating a function to send a query and get results from the the above chain
def get_response(query):
  results=RetrievalQA.from_chain_type(llm=llm,chain_type="stuff",retriever=vectordabase.as_retriever())
  return results.run(query)

# %%
get_response("what are the projects mujeeb worked on?")
# Out:
# ' Mujeeb worked on developing and deploying various applications such as RAG interactions, data analysis, conversational bots, skills generation, text and image applications, SQL query generator, and sentiment analysis. He also worked on projects involving health insurance and student placement prediction.'

# %%
# %%capture
pip install gradio

# %%
import pandas as pd

# %%
import gradio as gr
def get_response(query,history):
  results=RetrievalQA.from_chain_type(llm=llm,chain_type="stuff",retriever=vectordabase.as_retriever())
  return results.run(query)


gr.ChatInterface(
    get_response,
    chatbot=gr.Chatbot(height=300),
    textbox=gr.Textbox(placeholder="Ask me a yes or no question", container=False, scale=7),
    title="Q and A with PDF",
    description="Ask Yes Man any question",
    theme="soft",
    examples=["What are mujeeb's skiils?", "What are the projects Mujeeb worked on?", "when did he graduate?"],
    cache_examples=True,
    retry_btn=None,
    undo_btn="Delete Previous",
    clear_btn="Clear",
).launch(share=True)
# Out:
# Caching examples at: '/content/gradio_cached_examples/99'
# Caching example 1/3
# Caching example 2/3
# Caching example 3/3
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://ed0ddd6fefa2215f61.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ed0ddd6fefa2215f61.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # An application which interacts with Odinschools' website

# %%
# %%capture
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate transformers
# !pip -q install sentence_transformers

# %%
# %%capture
# !pip -q install unstructured # urls, pypdf-pdfs
# !pip install faiss-cpu # vectordatabase

# %%
#  integrate huggingface with colab
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
from langchain.vectorstores import FAISS # database
from langchain.embeddings import HuggingFaceEmbeddings # this is to create embeddings with a embedding model
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader

# %%
# %%capture
pip install numpy==1.24.4

# %%
URLS=["https://www.odinschool.com/"]

# %%
# extract the data for the URL
loaders=UnstructuredURLLoader(urls=URLS)

# %%
data=loaders.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# data

# %%
text_chunks=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

# %%
chunks=text_chunks.split_documents(data)

# %%
len(chunks)
# Out:
# 17

# %%
embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
vectordatabase=FAISS.from_documents(chunks,embeddings)

# %%
model="google/flan-t5-large"

# %%
from transformers import AutoTokenizer,AutoModelForSeq2SeqLM,pipeline
from langchain import HuggingFacePipeline

# %%
tokenizer1=AutoTokenizer.from_pretrained(model) # to generate tokens
model1=AutoModelForSeq2SeqLM.from_pretrained(model)
pipe=pipeline("text2text-generation",model=model1,tokenizer=tokenizer1)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
llm=HuggingFacePipeline(pipeline=pipe,model_kwargs={"temperature":0,"max_length":1000})
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   warn_deprecated(

# %%
from langchain.chains import RetrievalQA

# %%
from langchain.prompts import PromptTemplate
template="""use the context to provide a concise answer and if you don't know just say don't now.
{context}
Question: {question}
Helpful Answer:"""

prompt_template=PromptTemplate.from_template(template)

# %%
qa_chain=RetrievalQA.from_chain_type(llm,chain_type="stuff",retriever=vectordatabase.as_retriever()
,chain_type_kwargs={"prompt":prompt_template})

# %%
question="How much does it cost for a data science bootcamp at Odinschool?"
result=qa_chain({"query":question})
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Token indices sequence length is longer than the specified maximum sequence length for this model (881 > 512). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'query': 'How much does it cost for a data science bootcamp at Odinschool?',
#  'result': "don't know"}

# %%
question="How much does it cost for a data science bootcamp?"
result=qa_chain({"query":question})
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
result["result"]
# Out:
# "don't know"

# %%
question="Are the classes online or offline?"
result=qa_chain({"query":question})
result
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'query': 'Are the classes online or offline?', 'result': 'online'}

# %%
result["result"]
# Out:
# 'online'

# %%
question="what is the phone number?"
result=qa_chain({"query":question})
result["result"]
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# '+91 935 501 1033'

# %%
def fetech(question,history):
  result=qa_chain({"query":question})
  return result["result"]

# %%
gr.ChatInterface(
    fetech,
    chatbot=gr.Chatbot(height=300),
    textbox=gr.Textbox(placeholder="Ask me a yes or no question", container=False, scale=7),
    title="Chat with website",
    description="Ask the chatbot any question",
    theme="soft",
    examples=["contact details", "data science bootcamp fee?", "placements info","webdevelopment fee"],
    cache_examples=True,
    retry_btn=None,
    undo_btn="Delete Previous",
    clear_btn="Clear",
).launch(share=True)
# Out:
# Caching examples at: '/content/gradio_cached_examples/117'
# Caching example 1/4
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Caching example 2/4
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Caching example 3/4
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ...

# %%
# Rag with MongoDB

# %%
# load the packages to implement rag with mongo db
# %%capture
# !pip install datasets pandas pymongo sentence_transformers

# %%
# %%capture
# !pip install -U transformers accelerate

# %%
from datasets import load_dataset
import pandas as pd

# %%
dataset=load_dataset("AIatMongoDB/embedded_movies")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset # meta data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['plot', 'genres', 'runtime', 'cast', 'num_mflix_comments', 'poster', 'title', 'fullplot', 'languages', 'directors', 'writers', 'awards', 'imdb', 'countries', 'type', 'plot_embedding', 'rated', 'metacritic'],
#         num_rows: 1500
#     })
# })

# %%
dataset_df=pd.DataFrame(dataset["train"])

# %%
dataset_df.head(2)
# Out:
#                                                 plot                   genres  \
# 0  Young Pauline is left a lot of money when her ...                 [Action]
# 1  A penniless young man tries to save an heiress...  [Comedy, Short, Action]
#
#    runtime                                               cast  \
# 0    199.0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...
# 1     22.0  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
#
#    num_mflix_comments                                             poster  \
# 0                   0  https://m.media-amazon.com/images/M/MV5BMzgxOD...
# 1                   0  https://m.media-amazon.com/images/M/MV5BNzE1OW...
#
#                    title                                           fullplot  \
# 0  The Perils of Pauline  Young Pauline is left a lot of money when her ...
# 1     From Hand to Mouth  As a penniless man worries about how he will m...
#
#    languages                             directors  \
# ...

# %%
dataset_df.isnull().sum()
# Out:
# plot                   27
# genres                  0
# runtime                15
# cast                    1
# num_mflix_comments      0
# poster                 89
# title                   0
# fullplot               48
# languages               1
# directors              13
# writers                13
# awards                  0
# imdb                    0
# countries               0
# type                    0
# plot_embedding         28
# rated                 308
# metacritic            928
# dtype: int64

# %%
dataset_df.shape
# Out:
# (1500, 18)

# %%
dataset_df["plot_embedding"][0]
# Out:
# [0.0007293965299999999,
#  -0.026834568000000003,
#  0.013515796,
#  -0.033257525,
#  -0.0012954280000000002,
#  0.022092875,
#  -0.015958885000000003,
#  0.018283758,
#  -0.030315313000000003,
#  -0.019479034000000003,
#  0.019400224,
#  0.0106917955,
#  -0.005001107,
#  0.017981656000000002,
#  0.0036416466000000003,
#  -0.012918158,
#  0.029816188,
#  -0.00018706948,
#  0.013193991,
#  -0.024483424,
#  -0.016011424,
#  0.0019275442,
#  -0.007467182,
#  -0.011768856000000001,
#  0.012859052000000001,
#  -0.011722884000000001,
#  -0.002154121,
#  -0.022539461,
#  0.0010910163,
#  -0.017351182,
#  -0.0051226050000000006,
#  -0.010035052000000001,
#  0.0073161307,
#  -0.04103338,
#  -0.021068355,
#  0.009877433000000001,
#  0.023918625000000002,
#  -0.0037828467,
#  0.0067776004,
#  0.021593750000000002,
#  0.018993042,
#  0.0034905956,
#  0.0053557493000000005,
#  0.0018257490000000002,
#  -0.026493061000000002,
#  0.021580614,
#  0.00048516980000000003,
#  -0.02837135,
# ...

# %%
dataset_df = dataset_df.drop(columns=["plot_embedding"])

# %%
dataset_df.columns
# Out:
# Index(['plot', 'genres', 'runtime', 'cast', 'num_mflix_comments', 'poster',
#        'title', 'fullplot', 'languages', 'directors', 'writers', 'awards',
#        'imdb', 'countries', 'type', 'plot_embedding', 'rated', 'metacritic'],
#       dtype='object')

# %%
dataset_df=dataset_df.dropna(subset=["fullplot"])

# %%
dataset_df.isnull().sum()
# Out:
# plot                    0
# genres                  0
# runtime                14
# cast                    1
# num_mflix_comments      0
# poster                 78
# title                   0
# fullplot                0
# languages               1
# directors              12
# writers                13
# awards                  0
# imdb                    0
# countries               0
# type                    0
# rated                 279
# metacritic            893
# dtype: int64

# %%
dataset_df.shape
# Out:
# (1452, 17)

# %%
# embedding model
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-large")
# Out:
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
dataset_df["fullplot"][0:5]
# Out:
# 0    Young Pauline is left a lot of money when her ...
# 1    As a penniless man worries about how he will m...
# 2    Michael "Beau" Geste leaves England in disgrac...
# 3    A nobleman vows to avenge the death of his fat...
# 4    The Uptown Boy, J. Harold Manners (Lloyd) is a...
# Name: fullplot, dtype: object

# %%
text=" Hi everyone we are learning Rag with mongodb "
text.strip()
# Out:
# 'Hi everyone we are learning Rag with mongodb'

# %%
embedding_model.encode(text)
# Out:
# array([ 0.00170757,  0.03144065, -0.01535919, ..., -0.01069687,
#        -0.02517776,  0.04029654], dtype=float32)

# %%
def get_embedding(text:str)->list[float]:

  if not text.strip():
    print("attempted to get embedding for empty text.")
    return []

  embedding=embedding_model.encode(text)
  return embedding.tolist()

# %%
# if i have a column in a df and i want to apply a certain function to each of the rows of that column
dataset_df["embedding"]=dataset_df["fullplot"].apply(get_embedding)

# %%
dataset_df["embedding"][0]
# Out:
# [-0.009285837411880493,
#  -0.005062109790742397,
#  -0.010958125814795494,
#  0.029197748750448227,
#  -0.0032040441874414682,
#  0.006529418285936117,
#  -0.0005196462734602392,
#  0.03404375910758972,
#  0.004956727381795645,
#  -0.005387585144490004,
#  0.028133053332567215,
#  0.005806763656437397,
#  0.008509237319231033,
#  -0.00633973116055131,
#  -0.026832515373826027,
#  0.0007219556719064713,
#  -0.0520186722278595,
#  -0.018970809876918793,
#  -0.034679435193538666,
#  -0.014942380599677563,
#  0.021869564428925514,
#  0.013537651859223843,
#  -0.07247655093669891,
#  -0.03980888053774834,
#  -0.00570263434201479,
#  0.03734814375638962,
#  0.03697190806269646,
#  -0.0009293010225519538,
#  0.056134432554244995,
#  0.04322364181280136,
#  -0.016124587506055832,
#  -0.01813979633152485,
#  0.018382977694272995,
#  -0.031032312661409378,
#  -0.006974267773330212,
#  -0.019166959449648857,
#  0.04368211701512337,
#  -0.0282314270734787,
#  -0.0007613599300384521,
# ...

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import pymongo

# %%
# !python -m pip install "pymongo[srv]"

# %%
# mongodb+srv://mujeebrahman:Mujju123@cluster0.hcvebpu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
uri="mongodb+srv://mujeebrahman:Mujju123@cluster0.hcvebpu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
from pymongo.mongo_client import MongoClient

# %%
# Create a new client and connect to the server
client = MongoClient(uri)

# %%
try:
  client.admin.command("ping")
  print("Succesfully connected to Mongodb")
except Exception as e:
  print(e)
# Out:
# Succesfully connected to Mongodb

# %%
def get_mongo_client(uri):
  try:
    client = MongoClient(uri)
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    return client
  except Exception as e:
    print(e)
    return None

# %%
mongo_client=get_mongo_client(uri)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db=mongo_client["embedding_movies"] # creating a db

# %%
collection=db["movie1"] # creating a collection as per mongodb

# %%
collection.insert_one({"name":"Mujeeb",
                       "designation": "genai engineer",
                       "location":"Hyderabad",
                       "email":"mujeebr46@gmail.com"})
# Out:
# InsertOneResult(ObjectId('666d35f91f1beb2bb675ab37'), acknowledged=True)

# %%
collection.insert_one({"name":"Avinash",
                       "designation": "ops manager",
                       "location":"Hyderabad"})
# Out:
# InsertOneResult(ObjectId('666d36291f1beb2bb675ab38'), acknowledged=True)

# %%
collection.delete_many({}) # delete the collection
# Out:
# DeleteResult({'n': 2, 'electionId': ObjectId('7fffffff000000000000018e'), 'opTime': {'ts': Timestamp(1718433396, 46), 't': 398}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1718433396, 47), 'signature': {'hash': b'vb\xa7\xeb\xd3\xedG\x177v\x04\xca\xc1z\x19\xe8c\xf2&\x87', 'keyId': 7314639264287817729}}, 'operationTime': Timestamp(1718433396, 46)}, acknowledged=True)

# %%
dataset_df.head(2)
# Out:
#                                                 plot                   genres  \
# 0  Young Pauline is left a lot of money when her ...                 [Action]
# 1  A penniless young man tries to save an heiress...  [Comedy, Short, Action]
#
#    runtime                                               cast  \
# 0    199.0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...
# 1     22.0  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
#
#    num_mflix_comments                                             poster  \
# 0                   0  https://m.media-amazon.com/images/M/MV5BMzgxOD...
# 1                   0  https://m.media-amazon.com/images/M/MV5BNzE1OW...
#
#                    title                                           fullplot  \
# 0  The Perils of Pauline  Young Pauline is left a lot of money when her ...
# 1     From Hand to Mouth  As a penniless man worries about how he will m...
#
#    languages                             directors  \
# ...

# %%
document=dataset_df.to_dict("records") # records is a name given to dict

# %%
collection.insert_many(document)
# Out:
# InsertManyResult([ObjectId('666d38bb1f1beb2bb675ab39'), ObjectId('666d38bb1f1beb2bb675ab3a'), ObjectId('666d38bb1f1beb2bb675ab3b'), ObjectId('666d38bb1f1beb2bb675ab3c'), ObjectId('666d38bb1f1beb2bb675ab3d'), ObjectId('666d38bb1f1beb2bb675ab3e'), ObjectId('666d38bb1f1beb2bb675ab3f'), ObjectId('666d38bb1f1beb2bb675ab40'), ObjectId('666d38bb1f1beb2bb675ab41'), ObjectId('666d38bb1f1beb2bb675ab42'), ObjectId('666d38bb1f1beb2bb675ab43'), ObjectId('666d38bb1f1beb2bb675ab44'), ObjectId('666d38bb1f1beb2bb675ab45'), ObjectId('666d38bb1f1beb2bb675ab46'), ObjectId('666d38bb1f1beb2bb675ab47'), ObjectId('666d38bb1f1beb2bb675ab48'), ObjectId('666d38bb1f1beb2bb675ab49'), ObjectId('666d38bb1f1beb2bb675ab4a'), ObjectId('666d38bb1f1beb2bb675ab4b'), ObjectId('666d38bb1f1beb2bb675ab4c'), ObjectId('666d38bb1f1beb2bb675ab4d'), ObjectId('666d38bb1f1beb2bb675ab4e'), ObjectId('666d38bb1f1beb2bb675ab4f'), ObjectId('666d38bb1f1beb2bb675ab50'), ObjectId('666d38bb1f1beb2bb675ab51'), ObjectId('666d38bb1f1beb2bb675
# ...

# %%
{
 "fields": [{
     "numDimensions": 1024,
     "path": "embedding",
     "similarity": "cosine",
     "type": "vector"
   }]
}
# Out:
# {'fields': [{'numDimensions': 1024,
#    'path': 'embedding',
#    'similarity': 'cosine',
#    'type': 'vector'}]}

# %%
def vector_search(user_query,collection):

  query_embedding=get_embedding(user_query)

  if query_embedding is None:
    return "Invalid query or embeddig is failed"

  pipeline=[

            { # dollar symbol in Mongodb
                "$vectorSearch":{

                "index": "vector_index",
                "queryVector": query_embedding,
                "path": "embedding",
                "numCandidates": 150,  # Number of candidate matches to consider
                "limit": 4,  # Return top 4 matches


                }

            },

              {
                 "$project":{

                # "_id": 0,  # Exclude the _id field
                "fullplot": 1,  # Include the plot field
                "title": 1,  # Include the title field
                "genres": 1,  # Include the genres field
                "score": {"$meta": "vectorSearchScore"},  # Include the search score
                 }

            }

           ]

  result=collection.aggregate(pipeline)
  return list(result)

# %%
vector_search("what is the best horror movie to watch and why?",collection)
# Out:
# [{'_id': ObjectId('666d38bb1f1beb2bb675ad34'),
#   'genres': ['Action', 'Horror', 'Thriller'],
#   'title': 'Pet Sematary II',
#   'fullplot': 'The "sematary" is up to its old zombie-raising tricks again. This time, the protagonists are Jeff Matthews, whose mother died in a Hollywood stage accident, and Drew Gilbert, a boy coping with an abusive stepfather.',
#   'score': 0.9052295684814453},
#  {'_id': ObjectId('666d38bb1f1beb2bb675afcf'),
#   'genres': ['Action', 'Horror', 'Sci-Fi'],
#   'title': 'Dawn of the Dead',
# ...

# %%
def get_search_result(query,collection):

  get_knowledge=vector_search(query,collection)

  search_result=""

  for result in get_knowledge:
        search_result += f"Title: {result.get('title', 'N/A')}, Plot: {result.get('fullplot', 'N/A')}\n"

  return search_result

# %%
query="what is the best horror movie to watch and why?"

source_information=get_search_result(query,collection)

# %%
source_information
# Out:
# 'Title: Pet Sematary II, Plot: The "sematary" is up to its old zombie-raising tricks again. This time, the protagonists are Jeff Matthews, whose mother died in a Hollywood stage accident, and Drew Gilbert, a boy coping with an abusive stepfather.\nTitle: Dawn of the Dead, Plot: Ana, a young beautiful nurse finishes her day-shift at the hospital to return home to her beloved husband, they make love and sleep together. The next day, after her husband is killed by her neighbor next door, he suddenly comes back to life. She discovers the chaos happening in her neighborhood and escapes from her home. Soon after coming to her senses in the woods, she encounters a cop and other survivors, they decide to find safety in a mall. Soon more survivors come, and they learn that if they want to stay alive, they should stick together as the world is overrun by an army of undead. Can they survive the horror in this horrific global chaos? When there is no more room in hell, the dead will walk the eart
# ...

# %%
combined_information = f"Query: {query}\nContinue to answer the query by using the Search Results:\n{source_information}."

print(combined_information)
# Out:
# Query: what is the best horror movie to watch and why?
# Continue to answer the query by using the Search Results:
# Title: Pet Sematary II, Plot: The "sematary" is up to its old zombie-raising tricks again. This time, the protagonists are Jeff Matthews, whose mother died in a Hollywood stage accident, and Drew Gilbert, a boy coping with an abusive stepfather.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# Out:
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %%
# CPU Enabled uncomment below 👇🏽
# model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
# # Moving tensors to GPU
input_ids = tokenizer(combined_information, return_tensors="pt").to("cuda")

# %%
input_ids
# Out:
# {'input_ids': tensor([[     2,   5098, 235292,   1212,    603,    573,   1963,  24014,   7344,
#             577,   4234,    578,   3165, 235336,    108,  20017,    577,   3448,
#             573,   8164,    731,   2177,    573,  10552,   9467, 235292,    108,
#            4883, 235292,   7040,   9493,    482,    828,   2515, 235269,  32100,
#          235292,    714,    664,    497,    771,    828, 235281,    603,    908,
#             577,   1277,   2187,  50355, 235290,  33323,  35333,   1653, 235265,
#            1417,   1069, 235269,    573, 143074,    708,  13003,  61759, 235269,
#            6305,   5290,   7404,    575,    476,  22397,   6325,  10764, 235269,
#             578,  49273,  36816, 235269,    476,   5780,  66278,    675,    671,
#           74771, 212307, 235265,    108,   4883, 235292,  36272,    576,    573,
#           16138, 235269,  32100, 235292,  15769, 235269,    476,   3486,   4964,
# ...

# %%
response = model.generate(**input_ids, max_new_tokens=500)

# %%
print(tokenizer.decode(response[0]))
# Out:
# <bos>Query: what is the best horror movie to watch and why?
# Continue to answer the query by using the Search Results:
# Title: Pet Sematary II, Plot: The "sematary" is up to its old zombie-raising tricks again. This time, the protagonists are Jeff Matthews, whose mother died in a Hollywood stage accident, and Drew Gilbert, a boy coping with an abusive stepfather.
# ...
