# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshdasrla/odin_python/blob/main/GenAI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts

# %%
from gtts import gTTS
import IPython.display as ipd

text = "Namaste nenu telugu kuda matlda galanu"

tts = gTTS(text=text, lang='te')
tts.save('hello.mp3')

ipd.Audio('hello.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
