# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshdasrla/odin_python/blob/main/Python_Week2_Day1_StudentNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "A 'for' loop is a control flow statement used in programming to repeatedly execute a block of code for a fixed number of times or iterate over a sequence of elements, performing a specific action on each element

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **range() function:**
#
# The range() function is used to generate a sequence of numbers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://shorturl.at/fituV" height=350/>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Break:**
#
# The break statement terminates the loop immediately when it's encountered.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Continue:**
#
# The continue statement skips the current iteration of the loop and the control flow of the program goes to the next iteration.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://pythontutor.com/render.html#mode=display
